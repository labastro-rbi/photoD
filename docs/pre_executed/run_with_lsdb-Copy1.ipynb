# %% [markdown]
# ## Running PhotoD with LSDB

# %%
import os
default_n_threads = 1
os.environ['OPENBLAS_NUM_THREADS'] = f"{default_n_threads}"
os.environ['XLA_PYTHON_CLIENT_PREALLOCATE'] = 'false'

import jax
import lsdb
import matplotlib.pyplot as plt
import nested_pandas as npd
import numpy as np
import pandas as pd

from dask import delayed
from dask.distributed import Client, get_worker
from scipy.interpolate import griddata
from photod.bayes import makeBayesEstimates3d
from photod.locus import LSSTsimsLocus, subsampleLocusData, get3DmodelList
from photod.parameters import GlobalParams

# %%
# s82_stripe_url = "/mnt/beegfs/scratch/data/S82_standards/S82_hats/S82_hats_fixed"
s82_stripe_url = "/mnt/beegfs/scratch/data/Gaia-SDSS/hats/Gaia-SDSS_w_extinctions"
s82_stripe_catalog = lsdb.read_hats(s82_stripe_url)
s82_stripe_catalog
# Out:
# Dask NestedFrame Structure:
#                        random_index               ra              dec phot_g_mean_mag         parallax  parallax_error       source_id       r_med_geo        r_lo_geo        r_hi_geo  r_med_photogeo   r_lo_photogeo   r_hi_photogeo             flag           objid            type        psfmag_u        psfmag_g        psfmag_r        psfmag_i        psfmag_z     psfmagerr_u     psfmagerr_g     psfmagerr_r     psfmagerr_i     psfmagerr_z    extinction_u    extinction_g    extinction_r    extinction_i    extinction_z          Norder              Dir             Npix
# npartitions=63
# 0                    int64[pyarrow]  double[pyarrow]  double[pyarrow]  float[pyarrow]  double[pyarrow]  float[pyarrow]  int64[pyarrow]  float[pyarrow]  float[pyarrow]  float[pyarrow]  float[pyarrow]  float[pyarrow]  float[pyarrow]  string[pyarrow]  int64[pyarrow]  int16[pyarrow]  float[pyarrow]  float[pyarrow]  float[pyarrow]  float[pyarrow]  float[pyarrow]  float[pyarrow]  float[pyarrow]  float[pyarrow]  float[pyarrow]  float[pyarrow]  float[pyarrow]  float[pyarrow]  float[pyarrow]  float[pyarrow]  float[pyarrow]  uint8[pyarrow]  uint64[pyarrow]  uint64[pyarrow]
# 72057594037927936               ...              ...              ...             ...              ...             ...             ...             ...             ...             ...             ...             ...             ...              ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...              ...              ...
# ...                             ...              ...              ...             ...              ...             ...             ...             ...             ...             ...             ...             ...             ...              ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...              ...              ...
# 3170534137668829184             ...              ...              ...             ...              ...             ...             ...             ...             ...             ...             ...             ...             ...              ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...              ...              ...
# 3458764513820540928             ...              ...              ...             ...              ...             ...             ...             ...             ...             ...             ...             ...             ...              ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...              ...              ...
# Dask Name: nestedframe, 3 expressions
# Expr=MapPartitions(NestedFrame)

# %%
# prior_map_url = "/mnt/beegfs/scratch/data/priors/hats/s82_priors"
prior_map_url = "/mnt/beegfs/scratch/data/priors/TRILEGAL/level_5/"
prior_map_catalog = lsdb.read_hats(prior_map_url)
prior_map_catalog
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/hats/loaders/read_hats.py:40, in read_hats(catalog_path)
#      39 try:
# ---> 40     properties = TableProperties.read_from_dir(catalog_path)
#      41     dataset_type = properties.catalog_type
#
# File /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/hats/catalog/dataset/table_properties.py:200, in TableProperties.read_from_dir(cls, catalog_dir)
#     199 if not file_io.does_file_or_directory_exist(file_path):
# --> 200     raise FileNotFoundError(f"No properties file found where expected: {str(file_path)}")
#     201 p = Properties()
#
# FileNotFoundError: No properties file found where expected: /mnt/beegfs/scratch/data/priors/TRILEGAL/level_5/properties
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 3
#       1 # prior_map_url = "/mnt/beegfs/scratch/data/priors/hats/s82_priors"
#       2 prior_map_url = "/mnt/beegfs/scratch/data/priors/TRILEGAL/level_5/"
# ----> 3 prior_map_catalog = lsdb.read_hats(prior_map_url)
#       4 prior_map_catalog
#
# File /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/lsdb/loaders/hats/read_hats.py:72, in read_hats(path, search_filter, columns, margin_cache, dtype_backend, **kwargs)
#      63 # Creates a config object to store loading parameters from all keyword arguments.
#      64 config = HatsLoadingConfig(
#      65     search_filter=search_filter,
#      66     columns=columns,
#    (...)
#      69     kwargs=kwargs,
#      70 )
# ---> 72 hc_catalog = hc.read_hats(path)
#      73 if hc_catalog.schema is None:
#      74     raise ValueError(
#      75         "The catalog schema could not be loaded from metadata."
#      76         " Ensure your catalog has _common_metadata or _metadata files"
#      77     )
#
# File /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/hats/loaders/read_hats.py:58, in read_hats(catalog_path)
#      56     return loader(**kwargs)
#      57 except Exception as exception:  # pylint: disable=broad-except
# ---> 58     raise FileNotFoundError(f"Failed to read HATS at location {catalog_path}") from exception
#
# FileNotFoundError: Failed to read HATS at location /mnt/beegfs/scratch/data/priors/TRILEGAL/level_5

# %%
def merging_function(partition, map_partition, partition_pixel, map_pixel, globalParams, worker_dict, *kwargs):
    priorGrid = {}
    for rind, r in enumerate(np.sort(map_partition["rmag"].to_numpy())):
        # interpolate prior map onto locus Mr-FeH grid
        Z = map_partition[map_partition["rmag"] == r]
        Zval = np.frombuffer(Z.iloc[0]["kde"], dtype=np.float64).reshape((96, 36))
        X = np.frombuffer(Z.iloc[0]["xGrid"], dtype=np.float64).reshape((96, 36))
        Y = np.frombuffer(Z.iloc[0]["yGrid"], dtype=np.float64).reshape((96, 36))
        points = np.array((X.flatten(), Y.flatten())).T
        values = Zval.flatten()
        # actual (linear) interpolation
        priorGrid[rind] = griddata(
            points, values, (globalParams.locusData["FeH"], globalParams.locusData[globalParams.MrColumn]), method="linear", fill_value=0
        )
    gpu_device = jax.devices()[worker_dict[get_worker().id]]
    with jax.default_device(gpu_device):
        priorGrid = jax.numpy.array(list(priorGrid.values()))
        estimatesDf, _ = makeBayesEstimates3d(partition, priorGrid, globalParams, batchSize=10)
    # Append ra and dec to be able to later crossmatch
    return pd.concat([partition[["ra", "dec"]], npd.NestedFrame(estimatesDf)], axis=1)

# %%
# locus_path = "/home/scampos/photoD/data/MSandRGBcolors_v1.3.txt"
locus_path = "../../data/MSandRGBcolors_v1.3.txt"
fitColors = ("ug", "gr", "ri", "iz")
LSSTlocus = LSSTsimsLocus(fixForStripe82=False, datafile=locus_path)
OKlocus = LSSTlocus[(LSSTlocus["gi"] > 0.2) & (LSSTlocus["gi"] < 3.55)]
locusData = subsampleLocusData(OKlocus, kMr=10, kFeH=2)
ArGridList, locus3DList = get3DmodelList(locusData, fitColors)
globalParams = GlobalParams(fitColors, locusData, ArGridList, locus3DList)
# Out:
# subsampled locus 2D grid in FeH and Mr from 51 1559 to: 25 155

# %%
quantile_cols = [f"{statisticsName}_quantile_{quantile}" for statisticsName in ["Mr","FeH","Ar","Qr"] for quantile in ["lo","median","hi"]]
estimate_cols = sorted([*quantile_cols,"MrdS","FeHdS","ArdS"])
col_names = ["ra","dec","glon","glat","chi2min",*estimate_cols]
meta = npd.NestedFrame.from_dict({ col: pd.Series([], dtype=np.float32) for col in col_names })
meta.index.name = "_healpix_29"
meta
# Out:
# Empty NestedFrame
# Columns: [ra, dec, glon, glat, chi2min, Ar_quantile_hi, Ar_quantile_lo, Ar_quantile_median, ArdS, FeH_quantile_hi, FeH_quantile_lo, FeH_quantile_median, FeHdS, Mr_quantile_hi, Mr_quantile_lo, Mr_quantile_median, MrdS, Qr_quantile_hi, Qr_quantile_lo, Qr_quantile_median]
# Index: []

# %%
def get_worker_dict():
    res = s82_stripe_catalog._ddf.partitions[0:5].map_partitions(lambda df: pd.DataFrame.from_dict({"workers":[get_worker().id]}), meta={"workers": object}).compute()
    worker_ids = np.unique(res["workers"].to_numpy())
    worker_dict = {id: i for i, id in enumerate(worker_ids)}
    print(worker_dict)
    return worker_dict

# %%
# %%time
with Client(n_workers=4, dashboard_address=':41987') as client:  # threads_per_worker=1, memory_limit="auto",
    worker_dict = get_worker_dict()
    print(worker_dict)
    delayed_global_params = delayed(globalParams)
    merge_lazy = s82_stripe_catalog.merge_map(prior_map_catalog, merging_function, globalParams=delayed_global_params, worker_dict=worker_dict, meta=meta)
    xmatch_result = merge_lazy.compute()
xmatch_result
# Out:
# /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/node.py:187: UserWarning: Port 41987 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 35519 instead
#   warnings.warn(
# {'Worker-33aed7a3-94be-4691-b674-55721006b50a': 0, 'Worker-7971a1ed-2e9b-4f2c-946d-ecd0b2530eea': 1, 'Worker-90b3cfaa-b426-41a2-a806-aa4cdbffad59': 2, 'Worker-c3183a67-6e94-4020-a897-edecee95187e': 3}
# {'Worker-33aed7a3-94be-4691-b674-55721006b50a': 0, 'Worker-7971a1ed-2e9b-4f2c-946d-ecd0b2530eea': 1, 'Worker-90b3cfaa-b426-41a2-a806-aa4cdbffad59': 2, 'Worker-c3183a67-6e94-4020-a897-edecee95187e': 3}
# /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/client.py:3361: UserWarning: Sending large graph of size 82.79 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# 2024-12-18 17:11:16,017 - distributed.worker - ERROR - Compute Failed
# Key:       ('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 137)
# State:     executing
# Function:  execute_task
# args:      ((<function apply at 0x7f195c7793a0>, <function perform_merge_map at 0x7f18d2b62980>, [                     random_index          ra       dec  ...  Norder  Dir  Npix
# _healpix_29                                              ...
# 1333082597903076271    1229045708  326.210375 -9.070541  ...       2    0    74
# 1333082695467910450      91393013  326.190244 -9.068081  ...       2    0    74
# 1333082774583744613     615844200  326.198001   -9.0499  ...       2    0    74
# 1333082777060530646     135807859  326.200813 -9.049382  ...       2    0    74
# 1333082820343863188    1386888188  326.250405  -9.05296  ...       2    0    74
# ...                           ...         ...       ...  ...     ...  ...   ...
# 1351079709783125343     916205437  326.280993  9.557295  ...       2    0    74
# 1351079734149929664    1071852245  326.270955  9.557957  ...       2    0    74
# 1351079755965408895     743613725  326.234311  9.545518  ...       2    0    74
# 1351079809804786431    1365075695
# kwargs:    {}
# Exception: 'KeyError("None of [Index([\'ug\', \'gr\', \'ri\', \'iz\'], dtype=\'object\')] are in the [columns]")'
# Traceback: '  File "/nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/dask/utils.py", line 78, in apply\n    return func(*args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^\n  File "/nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/lsdb/dask/merge_map_catalog_data.py", line 60, in perform_merge_map\n    return func(catalog_partition, map_partition, catalog_pixel, map_pixel, *args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/tmp/ipykernel_3446340/1477576393.py", line 18, in merging_function\n  File "/mnt/beegfs/scratch/lovro/photod-cmu/photoD/src/photod/bayes.py", line 28, in makeBayesEstimates3d\n    selectedStars, colors, colorsErr, priorIndices = selectStarsInRange(starsData, globalParams, iStart, iEnd)\n                                                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/mnt/beegfs/scratch/lovro/photod-cmu/photoD/src/photod/bayes.py", line 48, in selectStarsInRange\n    colors = selectedStars[list(params.fitColors)].to_numpy(dtype=np.float64)\n             ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/nested_pandas/nestedframe/core.py", line 268, in __getitem__\n    return super().__getitem__(item)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/pandas/core/frame.py", line 4108, in __getitem__\n    indexer = self.columns._get_indexer_strict(key, "columns")[1]\n              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/pandas/core/indexes/base.py", line 6200, in _get_indexer_strict\n    self._raise_if_missing(keyarr, indexer, axis_name)\n  File "/nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/pandas/core/indexes/base.py", line 6249, in _raise_if_missing\n    raise KeyError(f"None of [{key}] are in the [{axis_name}]")\n'
#
# 2024-12-18 17:11:16,109 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 162))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,109 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 33))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,109 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 69))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,109 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 30))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,110 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 55))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,110 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 144))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,110 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 165))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,110 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 60))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,110 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 43))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,110 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 71))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,110 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 24))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,110 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 79))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,110 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 11))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,110 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 187))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,110 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 157))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,110 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 65))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,110 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 168))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,110 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 57))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,110 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 47))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,110 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 153))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,110 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 171))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,110 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 53))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,110 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 81))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,110 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 45))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,110 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 138))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,110 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 141))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,110 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 39))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,110 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 51))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,110 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 41))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,111 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 48))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,111 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 59))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,111 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 150))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,111 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 35))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,111 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 44))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,111 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 36))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,111 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 156))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,111 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 29))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,111 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 67))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,111 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 72))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,111 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 23))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,111 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 56))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,111 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 20))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,111 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 63))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,111 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 32))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,111 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 17))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,111 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 75))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,111 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 147))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,111 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 158))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,113 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 188))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,114 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 190))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,114 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 16))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,114 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 68))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,114 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 22))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,114 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 5))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,114 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 2))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,114 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 198))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,114 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 195))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,114 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 199))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,114 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 77))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,114 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 84))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,114 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 13))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,114 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 27))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,114 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 159))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,114 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 8))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,114 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 206))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,114 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 37))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,114 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 189))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,114 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 202))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,114 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 197))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,114 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 3))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,114 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 205))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,114 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 40))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,114 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 192))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,114 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 201))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,114 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 6))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,114 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 203))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,114 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 7))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,114 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 46))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,114 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 85))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,114 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 200))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,114 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 1))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,114 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 28))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,114 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 34))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,114 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 31))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,114 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 83))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,114 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 191))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,114 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 80))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,114 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 4))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,114 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 0))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,115 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 194))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,115 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 204))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,115 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 25))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,115 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 19))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,115 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 74))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,115 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 196))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,115 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 193))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,115 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 149))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,116 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 175))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,116 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 169))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,116 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 123))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,116 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 167))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,116 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 131))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,116 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 154))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,116 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 121))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,116 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 163))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,116 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 178))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,116 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 124))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,116 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 179))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,116 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 161))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,118 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 146))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,118 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 128))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,119 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 127))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,119 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 186))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,119 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 172))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,119 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 176))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,124 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 94))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,124 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 90))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,124 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 116))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,124 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 117))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# ...
# 2024-12-18 17:11:16,139 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 136))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,139 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 151))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,139 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 182))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,140 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 145))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,145 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 140))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,146 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 166))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,146 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 122))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,148 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 173))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,148 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 120))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,148 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 142))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,148 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 185))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,148 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 181))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,148 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 184))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,149 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 126))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:16,149 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('delayed-container-717cdf6ad6baaf15b881330b0453b96b', 155))" coro=<Worker.execute() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/worker_state_machine.py:3609>> ended with CancelledError
# 2024-12-18 17:11:20,102 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2024-12-18 17:11:20,103 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2024-12-18 17:11:20,124 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2024-12-18 17:11:20,124 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2024-12-18 17:11:21,117 - distributed.client - ERROR -
# Traceback (most recent call last):
#   File "/nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/utils.py", line 1921, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/utils.py", line 806, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/client.py", line 1938, in _close
#     await self.cluster.close()
#   File "/nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/deploy/spec.py", line 448, in _close
#     await self._correct_state()
#   File "/nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/deploy/spec.py", line 359, in _correct_state_internal
#     await asyncio.gather(*tasks)
#   File "/nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/nanny.py", line 619, in close
#     await self.kill(timeout=timeout, reason=reason)
#   File "/nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/nanny.py", line 400, in kill
#     await self.process.kill(reason=reason, timeout=timeout)
#   File "/nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/nanny.py", line 882, in kill
#     await process.join(max(0, deadline - time()))
#   File "/nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/process.py", line 330, in join
#     await wait_for(asyncio.shield(self._exit_future), timeout)
#   File "/nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/utils.py", line 1920, in wait_for
#     async with asyncio.timeout(timeout):
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
# 2024-12-18 17:11:21,124 - tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <tornado.platform.asyncio.AsyncIOMainLoop object at 0x7f58b84cd2b0>>, <Task finished name='Task-34982' coro=<SpecCluster._correct_state_internal() done, defined at /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/deploy/spec.py:346> exception=TimeoutError()>)
# Traceback (most recent call last):
#   File "/nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/utils.py", line 1921, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/tornado/ioloop.py", line 750, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/tornado/ioloop.py", line 774, in _discard_future_result
#     future.result()
# TimeoutError
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# File /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/utils.py:1921, in wait_for(fut, timeout)
#    1920 async with asyncio.timeout(timeout):
# -> 1921     return await fut
#
# CancelledError:
#
# The above exception was the direct cause of the following exception:
#
# TimeoutError                              Traceback (most recent call last)
# File <timed exec>:1
#
# File /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/client.py:1730, in Client.__exit__(self, exc_type, exc_value, traceback)
#    1723             raise  # pragma: nocover
#    1724         warnings.warn(
#    1725             "It is deprecated to enter and exit the Client context "
#    1726             "manager from different threads",
#    1727             DeprecationWarning,
#    1728             stacklevel=2,
#    1729         )
# -> 1730 self.close()
#
# File /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/client.py:1991, in Client.close(self, timeout)
#    1988         coro = wait_for(coro, timeout)
#    1989     return coro
# -> 1991 sync(self.loop, self._close, fast=True, callback_timeout=timeout)
#    1992 assert self.status == "closed"
#    1994 if not self._is_finalizing():
#
# File /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/utils.py:440, in sync(loop, func, callback_timeout, *args, **kwargs)
#     437         wait(10)
#     439 if error is not None:
# --> 440     raise error
#     441 else:
#     442     return result
#
# File /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/utils.py:414, in sync.<locals>.f()
#     412         awaitable = wait_for(awaitable, timeout)
#     413     future = asyncio.ensure_future(awaitable)
# --> 414     result = yield future
#     415 except Exception as exception:
#     416     error = exception
#
# File /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/tornado/gen.py:766, in Runner.run(self)
#     764 try:
#     765     try:
# --> 766         value = future.result()
#     767     except Exception as e:
#     768         # Save the exception for later. It's important that
#     769         # gen.throw() not be called inside this try/except block
#     770         # because that makes sys.exc_info behave unexpectedly.
#     771         exc: Optional[Exception] = e
#
# File /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/utils.py:1921, in wait_for(fut, timeout)
#    1919 async def wait_for(fut: Awaitable[T], timeout: float) -> T:
#    1920     async with asyncio.timeout(timeout):
# -> 1921         return await fut
#
# File /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/utils.py:806, in _LogErrors.__call__.<locals>.wrapper(*args, **kwargs)
#     804 async def wrapper(*args, **kwargs):
#     805     with self:
# --> 806         return await func(*args, **kwargs)
#
# File /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/client.py:1938, in Client._close(self, fast)
#    1936 if self._start_arg is None:
#    1937     with suppress(AttributeError):
# -> 1938         await self.cluster.close()
#    1940 await self.rpc.close()
#    1942 self.status = "closed"
#
# File /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/deploy/spec.py:448, in SpecCluster._close(self)
#     446 if isawaitable(f):
#     447     await f
# --> 448 await self._correct_state()
#     449 await asyncio.gather(*self._futures)
#     451 if self.scheduler_comm:
#
# File /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/deploy/spec.py:359, in SpecCluster._correct_state_internal(self)
#     353         await self.scheduler_comm.retire_workers(workers=list(to_close))
#     354     tasks = [
#     355         asyncio.create_task(self.workers[w].close())
#     356         for w in to_close
#     357         if w in self.workers
#     358     ]
# --> 359     await asyncio.gather(*tasks)
#     360 for name in to_close:
#     361     if name in self.workers:
#
# File /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/nanny.py:619, in Nanny.close(self, timeout, reason)
#     617 self.stop()
#     618 if self.process is not None:
# --> 619     await self.kill(timeout=timeout, reason=reason)
#     621 self.process = None
#     622 await self.rpc.close()
#
# File /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/nanny.py:400, in Nanny.kill(self, timeout, reason)
#     394 """Kill the local worker process
#     395
#     396 Blocks until both the process is down and the scheduler is properly
#     397 informed
#     398 """
#     399 if self.process is not None:
# --> 400     await self.process.kill(reason=reason, timeout=timeout)
#
# File /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/nanny.py:882, in WorkerProcess.kill(self, timeout, executor_wait, reason)
#     878     logger.warning(
#     879         f"Worker process still alive after {wait_timeout:.1f} seconds, killing"
#     880     )
#     881     await process.kill()
# --> 882     await process.join(max(0, deadline - time()))
#     883 except ValueError as e:
#     884     if "invalid operation on closed AsyncProcess" in str(e):
#
# File /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/process.py:330, in AsyncProcess.join(self, timeout)
#     327     return
#     328 # Shield otherwise the timeout cancels the future and our
#     329 # on_exit callback will try to set a result on a canceled future
# --> 330 await wait_for(asyncio.shield(self._exit_future), timeout)
#
# File /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/site-packages/distributed/utils.py:1920, in wait_for(fut, timeout)
#    1919 async def wait_for(fut: Awaitable[T], timeout: float) -> T:
# -> 1920     async with asyncio.timeout(timeout):
#    1921         return await fut
#
# File /nvme/lovro/miniconda3/envs/photod-testing/lib/python3.12/asyncio/timeouts.py:115, in Timeout.__aexit__(self, exc_type, exc_val, exc_tb)
#     110     self._state = _State.EXPIRED
#     112     if self._task.uncancel() <= self._cancelling and exc_type is exceptions.CancelledError:
#     113         # Since there are no new cancel requests, we're
#     114         # handling this.
# --> 115         raise TimeoutError from exc_val
#     116 elif self._state is _State.ENTERED:
#     117     self._state = _State.EXITED
#
# TimeoutError:

# %%
client.close()
