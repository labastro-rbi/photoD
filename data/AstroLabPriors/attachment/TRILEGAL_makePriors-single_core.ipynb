# %% [markdown]
# ### Using a TRILEGAL file for a given healpix,
# ### produce maps with Mr - [Fe/H] priors

# %%
# %matplotlib inline

import importlib

import sys
import pandas as pd
sys.path.append('.') # Force loading from this directory
import MakePriors_lp as mp
importlib.reload(mp)
# Out:
# <module 'MakePriors_lp' from '/mnt/beegfs/scratch/lovro/PhotoD/data/AstroLabPriors/attachment/MakePriors_lp.py'>

# %%
# fn = "/mnt/beegfs/scratch/lovro/temp/hipscat_dump_one_healpix_o8_h532725.csv"
fn= "/mnt/beegfs/scratch/lovro/temp/hipscat_dump_one_healpix_o4_h3050.csv"
# df = pd.read_csv("/mnt/beegfs/scratch/lovro/temp/hipscat_dump_one_healpix_o8_h532725.csv")
# df.rename(columns={"gall": "glon", "galb": "glat", "gc": "comp", "m_h": "FeH", "av": "Av",
#                    "mu0": "DM"}, inplace=True)
# df.to_csv("/mnt/beegfs/scratch/lovro/temp/hipscat_dump_one_healpix_o8_h532725.csv")

# %%
# Table.from_pandas(df).write("/mnt/beegfs/scratch/lovro/temp/hipscat_dump_one_healpix_o8_h532725.dat", format='ascii', overwrite=True)

# %%
df = mp.retrievePatch(fn)
# Out:
# retrieved patch with 2772927  entries

# %%
mp.printGalacticComponentStats(df)
# Out:
# Total: 2772927 Components 1-5: 649571 863156 1257277 2923 0
#            1 → thin disk; 2 → thick disk; 3 → halo; 4 → bulge; 5 → Magellanic Clouds
# (2772927,
#  0.23425463418258036,
#  0.3112797415871388,
#  0.4534115034402276,
#  0.0010541207900532541,
#  0.0)

# %%
mp.printPopulationStats(df)
# Out:
# Total: 2772927 Populations: 54217 2641961 15679 9378 2390 310 16 48976
#     Evolutionary phases: PMS=0, MS=1, SGB=2, RGB=3, CHeB=4,5,6, EAGB=7, TPAGB=8, PAGB+WD=9
#  Probabilities for MS, pMS, AGB and WD: 0.9717700674216816 0.010095596808780635 0.000119909810167322 0.018014425959370438
# (2718710,
#  0.9717700674216816,
#  0.010095596808780635,
#  0.000119909810167322,
#  0.018014425959370438)

# %%
mp.dumpCatalogFromPatch(df,"../../outputs/cat_from_patch_test")
# Out:
# dumping catalog...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 mp.dumpCatalogFromPatch(df,"../../outputs/cat_from_patch_test")
#
# File /mnt/beegfs/scratch/lovro/PhotoD/data/AstroLabPriors/attachment/MakePriors_lp.py:129, in dumpCatalogFromPatch(df, outfilename, verbose)
#     127 r6 = df['FeH'][i]
#     128 r7 = df['Mr'][i]
# --> 129 r8 = df['Ar'][i]
#     130 r9 = df['DM'][i]
#     131 s = s + str("%2.0f " % r1) + str("%5.2f  " % r2) + str("%6.3f  " % r3) + str("%2.0f  " % r4)
#
# File /nvme/lovro/miniconda3/envs/photoD-dev/lib/python3.12/site-packages/pandas/core/series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File /nvme/lovro/miniconda3/envs/photoD-dev/lib/python3.12/site-packages/pandas/core/series.py:1220, in Series._get_value(self, label, takeable)
#    1217     new_mgr = self._mgr.get_rows_with_mask(indexer)
#    1218     return self._constructor_from_mgr(new_mgr, axes=new_mgr.axes).__finalize__(self)
# -> 1220 def _get_value(self, label, takeable: bool = False):
#    1221     """
#    1222     Quickly retrieve single value at passed index label.
#    1223
#    (...)
#    1231     scalar value
#    1232     """
#    1233     if takeable:
#
# KeyboardInterrupt:

# %%
mp.dumpPriorsFromPatch(df,"../../outputs/")
# Out:
# dumping maps...
# r= 13.5 to 14.5 N= 2772927 Ns= 3355
# r= 14.0 to 15.0 N= 2772927 Ns= 4605
# r= 14.5 to 15.5 N= 2772927 Ns= 6292
# r= 15.0 to 16.0 N= 2772927 Ns= 8502
# r= 15.5 to 16.5 N= 2772927 Ns= 11409
# r= 16.0 to 17.0 N= 2772927 Ns= 15152
# r= 16.5 to 17.5 N= 2772927 Ns= 20087
# r= 17.0 to 18.0 N= 2772927 Ns= 26862
# r= 17.5 to 18.5 N= 2772927 Ns= 35642
# r= 18.0 to 19.0 N= 2772927 Ns= 46101
# r= 18.5 to 19.5 N= 2772927 Ns= 58721
# r= 19.0 to 20.0 N= 2772927 Ns= 73175
# r= 19.5 to 20.5 N= 2772927 Ns= 88653
# r= 20.0 to 21.0 N= 2772927 Ns= 104906
# r= 20.5 to 21.5 N= 2772927 Ns= 122912
# r= 21.0 to 22.0 N= 2772927 Ns= 144507
# r= 21.5 to 22.5 N= 2772927 Ns= 171459
# r= 22.0 to 23.0 N= 2772927 Ns= 206745
# subsampled for 2D map to n= 200000
# r= 22.5 to 23.5 N= 2772927 Ns= 253814
# subsampled for 2D map to n= 200000
# r= 23.0 to 24.0 N= 2772927 Ns= 312484
# subsampled for 2D map to n= 200000
# r= 23.5 to 24.5 N= 2772927 Ns= 378566
# subsampled for 2D map to n= 200000
# r= 24.0 to 25.0 N= 2772927 Ns= 444333
# subsampled for 2D map to n= 200000
# r= 24.5 to 25.5 N= 2772927 Ns= 501351
# subsampled for 2D map to n= 200000
# r= 25.0 to 26.0 N= 2772927 Ns= 542467
# subsampled for 2D map to n= 200000
# r= 25.5 to 26.5 N= 2772927 Ns= 563330
# subsampled for 2D map to n= 200000
# r= 26.0 to 27.0 N= 2772927 Ns= 565287
# subsampled for 2D map to n= 200000
# r= 26.5 to 27.5 N= 2772927 Ns= 551357
# subsampled for 2D map to n= 200000
# done with ../../outputs/

# %% [markdown]
# ## Scratch space

# %%
## automatically reload any modules read below that might have changed (e.g. plots)
# %reload_ext autoreload
# %autoreload 2
# importing plotting and locus tools: 
sys.path.append('../src')
import LocusTools as lt
import BayesTools as bt
import PlotTools as pt
import pandas as pd

# %%
# %%time
## TRILEGAL sims: read data file (such as Dani's three_pix_triout.dat)
trilegal = pd.read_csv("/mnt/beegfs/scratch/lovro/temp/hipscat_dump_one_healpix_o8_h532725.csv")
trilegal = lt.readTRILEGALLSDB(trilegal)
# absolute intrinsic r band magnitude
# trilegal = trilegal.to_pandas()
trilegal['Mr'] = trilegal['rmag'] - trilegal['Ar'] - trilegal['DM']  
# NB TRILEGAL sample is defined by r<27.5
# Out:
# CPU times: user 2.16 s, sys: 333 ms, total: 2.49 s
# Wall time: 2.82 s

# %%
# rootname = 'healPix1_priors'   # here healPix1 denotes Dani's three_pix_triout.dat file
# rootname = '/mnt/beegfs/scratch/lovro/temp/three_pix_triout.dat'
rootname = '/mnt/beegfs/scratch/lovro/temp/hipscat_dump_one_healpix_o8_h532725_rootname.csv'
# NB map parameters are set in dumpPriorMaps(), by calling getBayesConstants()
bt.dumpPriorMaps_testing(trilegal, rootname, show2Dmap=True)
# Out:
# sample <class 'pandas.core.frame.DataFrame'>
# Healpix:  -0.0
# ---------------------------------------
# tS <class 'pandas.core.frame.DataFrame'>
# r= 13.5 to 14.5 N= 1355720 Ns= 2
# ERROR: no data to make map (see dumpPriorMaps)
# tS <class 'pandas.core.frame.DataFrame'>
# r= 14.0 to 15.0 N= 1355720 Ns= 14
# tS <class 'pandas.core.frame.DataFrame'>
# r= 14.5 to 15.5 N= 1355720 Ns= 26
# tS <class 'pandas.core.frame.DataFrame'>
# r= 15.0 to 16.0 N= 1355720 Ns= 59
# tS <class 'pandas.core.frame.DataFrame'>
# r= 15.5 to 16.5 N= 1355720 Ns= 238
# tS <class 'pandas.core.frame.DataFrame'>
# r= 16.0 to 17.0 N= 1355720 Ns= 543
# tS <class 'pandas.core.frame.DataFrame'>
# r= 16.5 to 17.5 N= 1355720 Ns= 827
# tS <class 'pandas.core.frame.DataFrame'>
# r= 17.0 to 18.0 N= 1355720 Ns= 1142
# tS <class 'pandas.core.frame.DataFrame'>
# r= 17.5 to 18.5 N= 1355720 Ns= 1851
# tS <class 'pandas.core.frame.DataFrame'>
# r= 18.0 to 19.0 N= 1355720 Ns= 3160
# tS <class 'pandas.core.frame.DataFrame'>
# r= 18.5 to 19.5 N= 1355720 Ns= 9118
# tS <class 'pandas.core.frame.DataFrame'>
# r= 19.0 to 20.0 N= 1355720 Ns= 12389
# tS <class 'pandas.core.frame.DataFrame'>
# r= 19.5 to 20.5 N= 1355720 Ns= 10779
# tS <class 'pandas.core.frame.DataFrame'>
# r= 20.0 to 21.0 N= 1355720 Ns= 15319
# tS <class 'pandas.core.frame.DataFrame'>
# r= 20.5 to 21.5 N= 1355720 Ns= 26879
# tS <class 'pandas.core.frame.DataFrame'>
# r= 21.0 to 22.0 N= 1355720 Ns= 46924
# tS <class 'pandas.core.frame.DataFrame'>
# r= 21.5 to 22.5 N= 1355720 Ns= 72673
# tS <class 'pandas.core.frame.DataFrame'>
# r= 22.0 to 23.0 N= 1355720 Ns= 100609
# tS <class 'pandas.core.frame.DataFrame'>
# r= 22.5 to 23.5 N= 1355720 Ns= 130065
# tS <class 'pandas.core.frame.DataFrame'>
# r= 23.0 to 24.0 N= 1355720 Ns= 160761
# tS <class 'pandas.core.frame.DataFrame'>
# r= 23.5 to 24.5 N= 1355720 Ns= 195726
# tS <class 'pandas.core.frame.DataFrame'>
# r= 24.0 to 25.0 N= 1355720 Ns= 232418
# subsampled for 2D map to n= 200000
# tS <class 'pandas.core.frame.DataFrame'>
# r= 24.5 to 25.5 N= 1355720 Ns= 260677
# subsampled for 2D map to n= 200000
# tS <class 'pandas.core.frame.DataFrame'>
# r= 25.0 to 26.0 N= 1355720 Ns= 279724
# subsampled for 2D map to n= 200000
# tS <class 'pandas.core.frame.DataFrame'>
# r= 25.5 to 26.5 N= 1355720 Ns= 297504
# subsampled for 2D map to n= 200000
# tS <class 'pandas.core.frame.DataFrame'>
# r= 26.0 to 27.0 N= 1355720 Ns= 313085
# subsampled for 2D map to n= 200000
# tS <class 'pandas.core.frame.DataFrame'>
# r= 26.5 to 27.5 N= 1355720 Ns= 348005
# subsampled for 2D map to n= 200000

# %%
# test by reading back
bc = bt.getBayesConstants()
rmagMin = bc['rmagMin']
rmagMax = bc['rmagMax'] 
rmagNsteps = bc['rmagNsteps']  
priors, rmagBinWidth = bt.readPrior(rmagMin, rmagMax, rmagNsteps,rootname)

# %%
rmagBinWidth
# Out:
# 0.5

# %%
priors[0]['metadata'][0], priors[0]['metadata'][1], priors[0]['metadata'][2]
# Out:
# (-2.5, 1.0, 36.0)

# %%
# plot one map
rObs = 19
mapIndex = bt.getPriorMapIndex(rObs) 
print('map for rObs =', rObs, 'map index =', mapIndex)
pt.restore2Dmap(priors[mapIndex], logScale=True)
# Out:
# map for rObs = 19 map index = 10

# %%
# plot one map
rObs = 25
mapIndex = bt.getPriorMapIndex(rObs) 
print('map for rObs =', rObs, 'map index =', mapIndex)
pt.restore2Dmap(priors[mapIndex], logScale=True)
# Out:
# map for rObs = 25 map index = 22
